# %%
import pandas as pd

df=pd.read_pickle('broad_topic_df.pickle')
topics_dict = {
    'Technology/equipment': 'TECHNOLOGY',
    'Media/entertainment': 'TECHNOLOGY',
    'Internet and media': 'TECHNOLOGY',
    'Children': 'TECHNOLOGY',
    'Jobs & Institutions': 'JOB AND ECONOMY',
    'Finance and wealth': 'JOB AND ECONOMY',
    'Information and knowledge': 'JOB AND ECONOMY',
    'Brand/Product': 'JOB AND ECONOMY',
    'Social setting/impact': 'SOCIETY',
    'Language and communication': 'SOCIETY',
    'Family': 'SOCIETY',
    'Relationships': 'SOCIETY',
    'Culture': 'CULTURE',
    'Society & Culture': 'CULTURE',
    'Groups/Names': 'CULTURE',
    'Threat or Risk': 'VIOLENCE',
    'Insult': 'VIOLENCE',
    'Aggression and Violence': 'VIOLENCE',
    'Health Medicine': 'HEALTH',
    'Addictions/Drugs': 'HEALTH',
    'Food and drink': 'HEALTH',
    'Fitness and Skills': 'HEALTH',
    'Crime': 'LEGALITY',
    'Law and regulation': 'LEGALITY',
    'Safety': 'LEGALITY',
    'Life': 'ABSTRACT CONCEPT',
    'Death': 'ABSTRACT CONCEPT',
    'Abstraction': 'ABSTRACT CONCEPT',
    'Negative sentiments': 'ABSTRACT CONCEPT',
    'Identity': 'ABSTRACT CONCEPT',
    'Claim/Opinion': 'ABSTRACT CONCEPT',
    'Personal traits/taste': 'ABSTRACT CONCEPT',
    'Emotions': 'ABSTRACT CONCEPT',
    'Moral issues': 'ABSTRACT CONCEPT',
    'Behavior & Attitude': 'ABSTRACT CONCEPT',
    'Sexuality': 'SEXUALITY',
    'Gender': 'GENDER ISSUE',
    'Religion': 'DISCRIMINATION',
    'Race or ethnicity': 'DISCRIMINATION',
    'Racial stereotypes': 'DISCRIMINATION',
    'Locations/Geography': 'GEOPOLITICAL ISSUE',
    'Politics': 'GEOPOLITICAL ISSUE',
    'Geopolitics/National Issue': 'GEOPOLITICAL ISSUE',
    'War': 'GEOPOLITICAL ISSUE',
    'Environment': 'GEOPOLITICAL ISSUE',
    'Migration': 'GEOPOLITICAL ISSUE',
    'Time & Events': 'OTHER',
    'History': 'OTHER',
    'Animals': 'OTHER',
    'Personal tastes & Art': 'OTHER'
}

# %%
import ast 

conflicts=0

df=pd.read_pickle('broad_topic_df.pickle')
for topics in df['topics']:
    aggregations=[]
    topics=ast.literal_eval(topics)
    previous_topic=''

    for t in topics:
        #print(type(topics))
        macro_topic=topics_dict[t]
        aggregations.append(macro_topic)

    if len(aggregations)>1 and aggregations[0]==aggregations[1]:
        conflicts=conflicts+1
        print(aggregations)
        for t in topics:
            print(t)


print("total number of sentences",len(df))
print("conflicts", conflicts)
# Out:
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Environment
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Identity
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Abstraction
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Identity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['CULTURE', 'CULTURE']
# Groups/Names
# Culture
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Identity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Identity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Identity
# Emotions
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Death
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Abstraction
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Emotions
# ['TECHNOLOGY', 'TECHNOLOGY']
# Technology/equipment
# Children
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Emotions
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Brand/Product
# ['CULTURE', 'CULTURE', 'GEOPOLITICAL ISSUE']
# Groups/Names
# Society & Culture
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Claim/Opinion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Life
# ['OTHER', 'OTHER']
# Animals
# History
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['SOCIETY', 'SOCIETY']
# Family
# Relationships
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Identity
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Locations/Geography
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Jobs & Institutions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['SOCIETY', 'SOCIETY']
# Relationships
# Social setting/impact
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Jobs & Institutions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Personal traits/taste
# ['CULTURE', 'CULTURE']
# Groups/Names
# Society & Culture
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION', 'GEOPOLITICAL ISSUE']
# Racial stereotypes
# Race or ethnicity
# Environment
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE', 'DISCRIMINATION', 'JOB AND ECONOMY']
# Politics
# Locations/Geography
# Race or ethnicity
# Jobs & Institutions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['OTHER', 'OTHER']
# Personal tastes & Art
# Time & Events
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Locations/Geography
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Jobs & Institutions
# ['SOCIETY', 'SOCIETY']
# Relationships
# Social setting/impact
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Abstraction
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Personal traits/taste
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Behavior & Attitude
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Identity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Identity
# ['HEALTH', 'HEALTH']
# Health Medicine
# Addictions/Drugs
# ['TECHNOLOGY', 'TECHNOLOGY']
# Media/entertainment
# Internet and media
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Insult
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Life
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Abstraction
# Emotions
# ['VIOLENCE', 'VIOLENCE']
# Threat or Risk
# Insult
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Claim/Opinion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['OTHER', 'OTHER']
# Personal tastes & Art
# Time & Events
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['HEALTH', 'HEALTH']
# Health Medicine
# Food and drink
# ['OTHER', 'OTHER']
# Personal tastes & Art
# History
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION', 'OTHER']
# Race or ethnicity
# Religion
# Time & Events
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE', 'ABSTRACT CONCEPT']
# Migration
# Geopolitics/National Issue
# Identity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Identity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# ['OTHER', 'OTHER']
# Personal tastes & Art
# History
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Brand/Product
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['CULTURE', 'CULTURE']
# Groups/Names
# Society & Culture
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Personal traits/taste
# ['OTHER', 'OTHER']
# Personal tastes & Art
# Time & Events
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Personal traits/taste
# ['LEGALITY', 'LEGALITY']
# Safety
# Law and regulation
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Identity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['CULTURE', 'CULTURE']
# Groups/Names
# Culture
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION', 'ABSTRACT CONCEPT']
# Racial stereotypes
# Race or ethnicity
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Abstraction
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Abstraction
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Finance and wealth
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['LEGALITY', 'LEGALITY']
# Crime
# Law and regulation
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Identity
# ['HEALTH', 'HEALTH']
# Health Medicine
# Addictions/Drugs
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Death
# Claim/Opinion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Abstraction
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT', 'OTHER']
# Death
# Personal traits/taste
# Animals
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['HEALTH', 'HEALTH']
# Addictions/Drugs
# Food and drink
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Abstraction
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Identity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Politics
# ['HEALTH', 'HEALTH']
# Health Medicine
# Food and drink
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Identity
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Abstraction
# Emotions
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Death
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['TECHNOLOGY', 'TECHNOLOGY']
# Media/entertainment
# Technology/equipment
# ['OTHER', 'OTHER']
# Personal tastes & Art
# Time & Events
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# ['CULTURE', 'CULTURE']
# Groups/Names
# Society & Culture
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT', 'TECHNOLOGY']
# Negative sentiments
# Claim/Opinion
# Media/entertainment
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Life
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Claim/Opinion
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Jobs & Institutions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Abstraction
# ['OTHER', 'OTHER']
# Time & Events
# History
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Abstraction
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['SOCIETY', 'SOCIETY']
# Relationships
# Language and communication
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Abstraction
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Death
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['OTHER', 'OTHER']
# Personal tastes & Art
# Time & Events
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Behavior & Attitude
# ['OTHER', 'OTHER']
# Animals
# History
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Life
# ['TECHNOLOGY', 'TECHNOLOGY']
# Technology/equipment
# Children
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Brand/Product
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['TECHNOLOGY', 'TECHNOLOGY']
# Technology/equipment
# Media/entertainment
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Geopolitics/National Issue
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# ['DISCRIMINATION', 'DISCRIMINATION', 'GEOPOLITICAL ISSUE']
# Racial stereotypes
# Race or ethnicity
# Geopolitics/National Issue
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT', 'OTHER']
# Behavior & Attitude
# Emotions
# Time & Events
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Insult
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Identity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['SOCIETY', 'SOCIETY']
# Family
# Language and communication
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Locations/Geography
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Abstraction
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['OTHER', 'OTHER']
# Personal tastes & Art
# History
# ['VIOLENCE', 'VIOLENCE']
# Threat or Risk
# Insult
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['HEALTH', 'HEALTH']
# Health Medicine
# Addictions/Drugs
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['HEALTH', 'HEALTH']
# Health Medicine
# Food and drink
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['OTHER', 'OTHER']
# Animals
# History
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Abstraction
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Identity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Identity
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Death
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Finance and wealth
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['SOCIETY', 'SOCIETY']
# Relationships
# Social setting/impact
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Behavior & Attitude
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT', 'DISCRIMINATION']
# Claim/Opinion
# Life
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE', 'DISCRIMINATION']
# Geopolitics/National Issue
# Politics
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION', 'TECHNOLOGY']
# Racial stereotypes
# Race or ethnicity
# Technology/equipment
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Brand/Product
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Abstraction
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# War
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Identity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION', 'OTHER', 'HEALTH']
# Race or ethnicity
# Religion
# History
# Health Medicine
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['TECHNOLOGY', 'TECHNOLOGY']
# Media/entertainment
# Technology/equipment
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Abstraction
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Abstraction
# Identity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['SOCIETY', 'SOCIETY']
# Relationships
# Social setting/impact
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT', 'GEOPOLITICAL ISSUE']
# Life
# Abstraction
# Migration
# ['HEALTH', 'HEALTH']
# Health Medicine
# Food and drink
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Abstraction
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Brand/Product
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Emotions
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Abstraction
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Abstraction
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Abstraction
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Claim/Opinion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Abstraction
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Behavior & Attitude
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Behavior & Attitude
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Behavior & Attitude
# ['SOCIETY', 'SOCIETY', 'SOCIETY']
# Relationships
# Social setting/impact
# Language and communication
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Death
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Death
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['HEALTH', 'HEALTH']
# Health Medicine
# Addictions/Drugs
# ['CULTURE', 'CULTURE']
# Groups/Names
# Culture
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Insult
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Insult
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['LEGALITY', 'LEGALITY']
# Crime
# Law and regulation
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION', 'JOB AND ECONOMY']
# Racial stereotypes
# Race or ethnicity
# Finance and wealth
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Identity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# War
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['CULTURE', 'CULTURE']
# Groups/Names
# Culture
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['TECHNOLOGY', 'TECHNOLOGY']
# Media/entertainment
# Children
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['VIOLENCE', 'VIOLENCE']
# Threat or Risk
# Insult
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION', 'GEOPOLITICAL ISSUE']
# Racial stereotypes
# Race or ethnicity
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['OTHER', 'OTHER']
# Personal tastes & Art
# Animals
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['TECHNOLOGY', 'TECHNOLOGY']
# Media/entertainment
# Children
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Behavior & Attitude
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Abstraction
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT', 'OTHER']
# Behavior & Attitude
# Personal traits/taste
# Time & Events
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Personal traits/taste
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Life
# ['OTHER', 'OTHER']
# Time & Events
# History
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Brand/Product
# Jobs & Institutions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['SOCIETY', 'SOCIETY', 'ABSTRACT CONCEPT']
# Relationships
# Social setting/impact
# Emotions
# ['SOCIETY', 'SOCIETY', 'VIOLENCE']
# Relationships
# Social setting/impact
# Insult
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Jobs & Institutions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['LEGALITY', 'LEGALITY', 'CULTURE']
# Safety
# Crime
# Society & Culture
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Identity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION', 'OTHER']
# Race or ethnicity
# Religion
# Time & Events
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['DISCRIMINATION', 'DISCRIMINATION', 'JOB AND ECONOMY']
# Race or ethnicity
# Religion
# Finance and wealth
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION', 'GEOPOLITICAL ISSUE']
# Racial stereotypes
# Race or ethnicity
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Identity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Jobs & Institutions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['OTHER', 'OTHER']
# Animals
# History
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Abstraction
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Claim/Opinion
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Brand/Product
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Abstraction
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['HEALTH', 'HEALTH']
# Health Medicine
# Addictions/Drugs
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Death
# Personal traits/taste
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Brand/Product
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Behavior & Attitude
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['VIOLENCE', 'VIOLENCE']
# Threat or Risk
# Insult
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Abstraction
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Jobs & Institutions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['LEGALITY', 'LEGALITY']
# Safety
# Crime
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Finance and wealth
# Brand/Product
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['CULTURE', 'CULTURE']
# Groups/Names
# Society & Culture
# ['SOCIETY', 'SOCIETY']
# Relationships
# Language and communication
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['VIOLENCE', 'VIOLENCE']
# Aggression and Violence
# Threat or Risk
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['OTHER', 'OTHER']
# Animals
# History
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Life
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Claim/Opinion
# ['CULTURE', 'CULTURE']
# Groups/Names
# Society & Culture
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['SOCIETY', 'SOCIETY']
# Relationships
# Social setting/impact
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Identity
# ['SOCIETY', 'SOCIETY']
# Relationships
# Social setting/impact
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['OTHER', 'OTHER']
# Personal tastes & Art
# Time & Events
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE', 'LEGALITY', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Geopolitics/National Issue
# Crime
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['VIOLENCE', 'VIOLENCE']
# Threat or Risk
# Insult
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Life
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Claim/Opinion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Behavior & Attitude
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Death
# ['HEALTH', 'HEALTH']
# Health Medicine
# Food and drink
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Identity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION', 'CULTURE']
# Racial stereotypes
# Race or ethnicity
# Groups/Names
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Life
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Behavior & Attitude
# ['SOCIETY', 'SOCIETY', 'ABSTRACT CONCEPT']
# Family
# Relationships
# Abstraction
# ['TECHNOLOGY', 'TECHNOLOGY']
# Technology/equipment
# Media/entertainment
# ['OTHER', 'OTHER']
# Time & Events
# History
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['CULTURE', 'CULTURE']
# Society & Culture
# Culture
# ['SOCIETY', 'SOCIETY']
# Family
# Relationships
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Abstraction
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Identity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Identity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Brand/Product
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT', 'DISCRIMINATION']
# Claim/Opinion
# Life
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Moral issues
# Claim/Opinion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Abstraction
# Emotions
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['OTHER', 'OTHER']
# Animals
# Time & Events
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Personal traits/taste
# ['VIOLENCE', 'VIOLENCE']
# Threat or Risk
# Insult
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Emotions
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Information and knowledge
# Jobs & Institutions
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['OTHER', 'OTHER']
# Personal tastes & Art
# Animals
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['OTHER', 'OTHER']
# Time & Events
# History
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['SOCIETY', 'SOCIETY']
# Social setting/impact
# Language and communication
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['JOB AND ECONOMY', 'JOB AND ECONOMY']
# Brand/Product
# Jobs & Institutions
# ['OTHER', 'OTHER']
# Animals
# History
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['HEALTH', 'HEALTH']
# Health Medicine
# Food and drink
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION', 'CULTURE']
# Race or ethnicity
# Religion
# Culture
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE', 'OTHER']
# Environment
# Locations/Geography
# Time & Events
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Death
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Death
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['TECHNOLOGY', 'TECHNOLOGY']
# Technology/equipment
# Children
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Behavior & Attitude
# Emotions
# ['SOCIETY', 'SOCIETY']
# Relationships
# Social setting/impact
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION', 'CULTURE']
# Racial stereotypes
# Race or ethnicity
# Groups/Names
# ['SOCIETY', 'SOCIETY']
# Family
# Social setting/impact
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# War
# Politics
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# ['TECHNOLOGY', 'TECHNOLOGY']
# Media/entertainment
# Technology/equipment
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Abstraction
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Personal traits/taste
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Life
# ['SOCIETY', 'SOCIETY']
# Social setting/impact
# Language and communication
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Migration
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Politics
# Migration
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Emotions
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Negative sentiments
# Personal traits/taste
# ['SOCIETY', 'SOCIETY']
# Relationships
# Social setting/impact
# ['OTHER', 'OTHER']
# History
# Time & Events
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Locations/Geography
# Migration
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Locations/Geography
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Claim/Opinion
# Emotions
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Claim/Opinion
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Life
# Personal traits/taste
# ['ABSTRACT CONCEPT', 'ABSTRACT CONCEPT']
# Personal traits/taste
# Identity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Religion
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Environment
# Migration
# ['DISCRIMINATION', 'DISCRIMINATION']
# Race or ethnicity
# Religion
# ['OTHER', 'OTHER']
# Animals
# History
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['GEOPOLITICAL ISSUE', 'GEOPOLITICAL ISSUE']
# Geopolitics/National Issue
# Politics
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['DISCRIMINATION', 'DISCRIMINATION']
# Racial stereotypes
# Race or ethnicity
# ['HEALTH', 'HEALTH']
# Health Medicine
# Fitness and Skills
# total number of sentences 12914
# conflicts 867

# %%
import pandas as pd
import ast
df=pd.read_csv('broad_topic_df.csv')

df['TECHNOLOGY']=None
df['JOB AND ECONOMY']=None
df['SOCIETY']=None
df['CULTURE']=None
df['VIOLENCE']=None
df['HEALTH']=None
df['LEGALITY']=None
df['SEXUALITY']=None
df['GENDER ISSUE']=None
df['ABSTRACT CONCEPT']=None
df['DISCRIMINATION']=None
df['GEOPOLITICAL ISSUE']=None
df['OTHER']=None

print(df.columns)
for index, row in df.iterrows():
    topics=ast.literal_eval(row['topics'])
    for t in topics:
        #print(type(topics))
        macro_topic=topics_dict[t]
    
        row[macro_topic]= t
        df.iloc[index]=row

df.head()
# Out:
# Index(['text', 'sentence_number', 'topics', 'label', 'TECHNOLOGY',
#        'JOB AND ECONOMY', 'SOCIETY', 'CULTURE', 'VIOLENCE', 'HEALTH',
#        'LEGALITY', 'SEXUALITY', 'GENDER ISSUE', 'ABSTRACT CONCEPT',
#        'DISCRIMINATION', 'GEOPOLITICAL ISSUE', 'OTHER'],
#       dtype='object')
#                                                 text  sentence_number  \
# 0  social services have a love/hate relationship ...                0
# 1  Yes it's a joke and offensive isn't it? Why ar...                1
# 2  I do not have passions in life, and I'm not su...                2
# 3  You better be. That was the most half-assed co...                3
# 4  Waging war on, and bombing, a foreign sovereig...                4
#
#                                        topics    label TECHNOLOGY  \
# 0  ['Health Medicine', 'Jobs & Institutions']  nothate       None
# 1         ['Gender', 'Social setting/impact']  nothate       None
# 2          ['Claim/Opinion', 'Relationships']  nothate       None
# 3   ['Culture', 'Language and communication']  nothate       None
# 4                ['Race or ethnicity', 'War']     hate       None
#
#        JOB AND ECONOMY                     SOCIETY  CULTURE VIOLENCE  \
# 0  Jobs & Institutions                        None     None     None
# 1                 None       Social setting/impact     None     None
# 2                 None               Relationships     None     None
# 3                 None  Language and communication  Culture     None
# 4                 None                        None     None     None
#
#             HEALTH LEGALITY SEXUALITY GENDER ISSUE ABSTRACT CONCEPT  \
# 0  Health Medicine     None      None         None             None
# 1             None     None      None       Gender             None
# 2             None     None      None         None    Claim/Opinion
# 3             None     None      None         None             None
# 4             None     None      None         None             None
#
#       DISCRIMINATION GEOPOLITICAL ISSUE OTHER
# 0               None               None  None
# 1               None               None  None
# 2               None               None  None
# 3               None               None  None
# 4  Race or ethnicity                War  None

# %%
merged_df=pd.read_csv('merged_df.csv')
topics_and_labels= pd.merge(df, merged_df, on='text', how='inner')
print(len(topics_and_labels))


topics_and_labels = topics_and_labels.drop(columns=['topics_y','label_x', 'topics_x','sentence_number_x'])
topics_and_labels.head()
# Out:
# 12964
#                                                 text TECHNOLOGY  \
# 0  social services have a love/hate relationship ...       None
# 1  Yes it's a joke and offensive isn't it? Why ar...       None
# 2  I do not have passions in life, and I'm not su...       None
# 3  You better be. That was the most half-assed co...       None
# 4  Waging war on, and bombing, a foreign sovereig...       None
#
#        JOB AND ECONOMY                     SOCIETY  CULTURE VIOLENCE  \
# 0  Jobs & Institutions                        None     None     None
# 1                 None       Social setting/impact     None     None
# 2                 None               Relationships     None     None
# 3                 None  Language and communication  Culture     None
# 4                 None                        None     None     None
#
#             HEALTH LEGALITY SEXUALITY GENDER ISSUE ABSTRACT CONCEPT  \
# 0  Health Medicine     None      None         None             None
# 1             None     None      None       Gender             None
# 2             None     None      None         None    Claim/Opinion
# 3             None     None      None         None             None
# 4             None     None      None         None             None
#
#       DISCRIMINATION GEOPOLITICAL ISSUE OTHER  Unnamed: 0  sentence_number_y  \
# 0               None               None  None           0                  0
# 1               None               None  None           1                  1
# 2               None               None  None           2                  2
# 3               None               None  None           3                  3
# 4  Race or ethnicity                War  None           4                  4
#
#    label_y
# 0  nothate
# 1  nothate
# 2  nothate
# 3  nothate
# 4     hate

# %% [markdown]
# # NOT FINETUNED MODEL

# %% [markdown]
# ## FALSE POSITIVE ANALYSIS

# %%
from divexplorer import DivergenceExplorer
from divexplorer.outcomes import get_false_positive_rate_outcome, get_accuracy_outcome

predictions=pd.read_csv("classified_sentences_finetuned.csv")
predictions['text'] = predictions['text'].str.replace("^'", "", regex=True)
predictions['text'] = predictions['text'].str.replace("'$", "", regex=True)
predictions['text'] = predictions['text'].str.replace("^\"", "", regex=True)
predictions['text'] = predictions['text'].str.replace("\"$", "", regex=True)

#replace the " with ' 
predictions['text'] = predictions['text'].str.replace("\"", "'", regex=True)

final_df= pd.merge(topics_and_labels, predictions, on='text', how='inner')
""" print(len(final_df))

name_counts = predictions['text'].value_counts()

# Filter the DataFrame to remove rows where the count is 1
duplicates = predictions[predictions['text'].isin(name_counts[name_counts > 1].index)]

print(len(duplicates))
left_out_senteces= pd.merge(topics_and_labels, predictions, on ='text', how='left')
#print(topics_and_labels.iloc[192]['text'])
print(left_out_senteces[left_out_senteces['label'].isnull()].iloc[1]['text'])
"""

final_df = final_df.drop_duplicates(subset='text')
print("final length for divexplorer", len(final_df))
final_df = final_df.drop(columns=['label_y', 'Unnamed: 0','sentence_number_y'])
final_df.head()

final_df['label'] = final_df['label'].apply(lambda x: 0 if x == 'nothate' else 1)

y_trues = final_df["label"]
y_preds = final_df["prediction"]

final_df['fp'] =  get_false_positive_rate_outcome(y_trues, y_preds)


fp_diver = DivergenceExplorer(final_df)

attributes = ['TECHNOLOGY', 'JOB AND ECONOMY', 'SOCIETY', 'CULTURE', 'VIOLENCE', 'HEALTH','LEGALITY', 'SEXUALITY', 
              'GENDER ISSUE','ABSTRACT CONCEPT', 'DISCRIMINATION','GEOPOLITICAL ISSUE', 'OTHER']
FP_fm = fp_diver.get_pattern_divergence(min_support=0.05, attributes=attributes,
                                        boolean_outcomes=['fp'])
FP_fm = FP_fm.sort_values(by="fp_div", ascending=False, ignore_index=True)
FP_fm
# Out:
# final length for divexplorer 12860
#      support                                   itemset        fp    fp_div  \
# 0   0.056454                     (SEXUALITY=Sexuality)  0.220657  0.107132
# 1   0.124806                     (GENDER ISSUE=Gender)  0.199170  0.085645
# 2   0.201711        (DISCRIMINATION=Race or ethnicity)  0.173844  0.060318
# 3   0.050622       (DISCRIMINATION=Racial stereotypes)  0.162791  0.049265
# 4   0.067418                 (DISCRIMINATION=Religion)  0.142857  0.029332
# 5   0.062986           (SOCIETY=Social setting/impact)  0.132626  0.019101
# 6   0.075272                     (OTHER=Time & Events)  0.123967  0.010442
# 7   0.074961  (ABSTRACT CONCEPT=Personal traits/taste)  0.119438  0.005913
# 8   0.058709                    (CULTURE=Groups/Names)  0.116550  0.003025
# 9   0.054510                 (VIOLENCE=Threat or Risk)  0.114914  0.001389
# 10  1.000000                                        ()  0.113525  0.000000
# 11  0.053421  (GEOPOLITICAL ISSUE=Locations/Geography)  0.102339 -0.011186
# 12  0.093546          (ABSTRACT CONCEPT=Claim/Opinion)  0.099115 -0.014410
# 13  0.058787                  (HEALTH=Health Medicine)  0.094955 -0.018570
# 14  0.071384             (GEOPOLITICAL ISSUE=Politics)  0.093474 -0.020051
# 15  0.051633               (ABSTRACT CONCEPT=Emotions)  0.037694 -0.075831
#
#         fp_t  length  support_count
# 0   3.827886       1          726.0
# 1   4.654938       1         1605.0
# 2   3.903558       1         2594.0
# 3   2.046449       1          651.0
# 4   1.530347       1          867.0
# 5   1.162651       1          810.0
# 6   0.693890       1          968.0
# 7   0.464481       1          964.0
# 8   0.290730       1          755.0
# 9   0.191611       1          701.0
# 10  0.000000       0        12860.0
# 11  0.530078       1          687.0
# 12  0.989005       1         1203.0
# 13  0.982842       1          756.0
# 14  1.448247       1          918.0
# 15  7.355217       1          664.0

# %%
from divexplorer import DivergenceExplorer, DivergencePatternProcessor
final_df['ac'] =  get_accuracy_outcome(y_trues, y_preds)


ac_diver = DivergenceExplorer(final_df)

attributes = ['TECHNOLOGY', 'JOB AND ECONOMY', 'SOCIETY', 'CULTURE', 'VIOLENCE', 'HEALTH','LEGALITY', 'SEXUALITY', 
              'GENDER ISSUE','ABSTRACT CONCEPT', 'DISCRIMINATION','GEOPOLITICAL ISSUE', 'OTHER']
ac_fm = ac_diver.get_pattern_divergence(min_support=0.05, attributes=attributes,
                                        boolean_outcomes=['ac'])
ac_fm = ac_fm.sort_values(by="ac_div", ascending=False, ignore_index=True)
ac_fm
# Out:
#      support                                   itemset        ac    ac_div  \
# 0   0.051633               (ABSTRACT CONCEPT=Emotions)  0.915663  0.086580
# 1   0.074961  (ABSTRACT CONCEPT=Personal traits/taste)  0.860996  0.031913
# 2   0.054510                 (VIOLENCE=Threat or Risk)  0.858773  0.029691
# 3   0.093546          (ABSTRACT CONCEPT=Claim/Opinion)  0.854530  0.025448
# 4   0.075272                     (OTHER=Time & Events)  0.846074  0.016992
# 5   0.067418                 (DISCRIMINATION=Religion)  0.840830  0.011748
# 6   0.201711        (DISCRIMINATION=Race or ethnicity)  0.836160  0.007078
# 7   0.053421  (GEOPOLITICAL ISSUE=Locations/Geography)  0.834061  0.004979
# 8   0.071384             (GEOPOLITICAL ISSUE=Politics)  0.831155  0.002072
# 9   1.000000                                        ()  0.829082  0.000000
# 10  0.058787                  (HEALTH=Health Medicine)  0.824074 -0.005008
# 11  0.056454                     (SEXUALITY=Sexuality)  0.818182 -0.010901
# 12  0.058709                    (CULTURE=Groups/Names)  0.800000 -0.029082
# 13  0.050622       (DISCRIMINATION=Racial stereotypes)  0.798771 -0.030311
# 14  0.062986           (SOCIETY=Social setting/impact)  0.791358 -0.037724
# 15  0.124806                     (GENDER ISSUE=Gender)  0.790031 -0.039051
#
#         ac_t  length  support_count
# 0   7.536537       1          664.0
# 1   2.683343       1          964.0
# 2   2.115443       1          701.0
# 3   2.328611       1         1203.0
# 4   1.353071       1          968.0
# 5   0.856291       1          867.0
# 6   0.859857       1         2594.0
# 7   0.278499       1          687.0
# 8   0.109627       1          918.0
# 9   0.000000       0        12860.0
# 10  0.408184       1          756.0
# 11  0.797980       1          726.0
# 12  1.998375       1          755.0
# 13  1.942287       1          651.0
# 14  2.620547       1          810.0
# 15  3.681505       1         1605.0

# %%
ac_details = DivergencePatternProcessor(ac_fm, 'ac')

# We can pick a pattern
pattern = ac_details.patterns['itemset'].iloc[0]

gsv = ac_details.global_shapley_value()

ac_details.plot_shapley_value(shapley_values=gsv, figsize=(3,4), title='Global Shapley Value Accuracy Finetuned')

# %%
from divexplorer import DivergencePatternProcessor
fp_details = DivergencePatternProcessor(FP_fm, 'fp')

# We can pick a pattern
pattern = fp_details.patterns['itemset'].iloc[0]

gsv = fp_details.global_shapley_value()
gsv
fp_details.plot_shapley_value(shapley_values=gsv, figsize=(3,4), title='Global Shapley Value False Positive Finetuned')

# %%
from divexplorer import DivergenceExplorer,DivergencePatternProcessor
from divexplorer.outcomes import get_false_negative_rate_outcome

final_df['fn'] =  get_false_negative_rate_outcome(y_trues, y_preds)


fn_diver = DivergenceExplorer(final_df)

attributes = ['TECHNOLOGY', 'JOB AND ECONOMY', 'SOCIETY', 'CULTURE', 'VIOLENCE', 'HEALTH','LEGALITY', 'SEXUALITY', 
              'GENDER ISSUE','ABSTRACT CONCEPT', 'DISCRIMINATION','GEOPOLITICAL ISSUE', 'OTHER']
FN_fm = fn_diver.get_pattern_divergence(min_support=0.05, attributes=attributes,
                                        boolean_outcomes=['fn'])
FN_fm = FN_fm.sort_values(by="fn_div", ascending=False, ignore_index=True)
fp_details = DivergencePatternProcessor(FP_fm, 'fp')

# We can pick a pattern
pattern = fp_details.patterns['itemset'].iloc[0]
print(pattern)

# and compute the Shapley value of the items.
sv = fp_details.shapley_value(pattern)
FN_fm
# Out:
# frozenset({'SEXUALITY=Sexuality'})
#      support                                   itemset        fn    fn_div  \
# 0   0.058709                    (CULTURE=Groups/Names)  0.309816  0.089680
# 1   0.071384             (GEOPOLITICAL ISSUE=Politics)  0.290598  0.070463
# 2   0.062986           (SOCIETY=Social setting/impact)  0.274827  0.054691
# 3   0.058787                  (HEALTH=Health Medicine)  0.241050  0.020914
# 4   0.053421  (GEOPOLITICAL ISSUE=Locations/Geography)  0.228986  0.008850
# 5   0.050622       (DISCRIMINATION=Racial stereotypes)  0.220183  0.000048
# 6   1.000000                                        ()  0.220136  0.000000
# 7   0.124806                     (GENDER ISSUE=Gender)  0.214604 -0.005532
# 8   0.093546          (ABSTRACT CONCEPT=Claim/Opinion)  0.186520 -0.033615
# 9   0.051633               (ABSTRACT CONCEPT=Emotions)  0.183099 -0.037037
# 10  0.054510                 (VIOLENCE=Threat or Risk)  0.178082 -0.042054
# 11  0.075272                     (OTHER=Time & Events)  0.171901 -0.048235
# 12  0.067418                 (DISCRIMINATION=Religion)  0.167845 -0.052291
# 13  0.056454                     (SEXUALITY=Sexuality)  0.165692 -0.054444
# 14  0.201711        (DISCRIMINATION=Race or ethnicity)  0.160651 -0.059485
# 15  0.074961  (ABSTRACT CONCEPT=Personal traits/taste)  0.154562 -0.065573
#
#         fn_t  length  support_count
# 0   3.490551       1          755.0
# 1   2.901180       1          918.0
# 2   2.532051       1          810.0
# 3   1.028927       1          756.0
# 4   0.446833       1          687.0
# 5   0.060908       1          651.0
# 6   0.000000       0        12860.0
# 7   0.386227       1         1605.0
# 8   2.019469       1         1203.0
# 9   1.268282       1          664.0
# 10  1.742122       1          701.0
# 11  2.928876       1          968.0
# 12  3.106738       1          867.0
# 13  3.102238       1          726.0
# 14  6.129093       1         2594.0
# 15  3.929115       1          964.0

# %%
from divexplorer import DivergencePatternProcessor
fn_details = DivergencePatternProcessor(FN_fm, 'fn')

# We can pick a pattern
pattern = fn_details.patterns['itemset'].iloc[0]
print(pattern)

gsv = fn_details.global_shapley_value()
fn_details.plot_shapley_value(shapley_values=gsv, figsize=(3,4), title='Global Shapley Value False Negative Finetuned')
# Out:
# frozenset({'CULTURE=Groups/Names'})

# %%
final_df[(final_df['label']== 1) & (final_df['prediction']==0) & (final_df['CULTURE']=='Groups/Names')].iloc[0]['text']
# Out:
# "I said something super lame the other day on the PAX discord and someone called me ableist. I was like...saaaaay what? I should have replied with 'that's gay' lol"
